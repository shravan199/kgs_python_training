# %%
from ex1_connect import *
conn,cur=connect()

# sql="select id,age,name from kpmgAug23"
sql="select * from kpmgAug23"

cur.execute(sql)
g=cur.fetchall()#return list of all rows(tuples)
print(g)
# Out:
# [(1, 'Manish', 23, 'manikpur                                          ', None), (2, 'Nishant', 25, None, 34.89), (3, 'Manish', 78, 'Test age                                          ', 345.898), (4, 'Nishant', 78, None, None), (5, 'Nishant', 78, 'New Data                                          ', 45.6996), (6, 'Nishant', 78, None, None), (7, 'Nishant', 78, None, None), (8, 'Raj', 98, None, None), (9, 'Nishant', 78, 'Mawan meerut                                      ', 478.979), (10, 'Raj', 98, 'Gol puri                                          ', 765.9), (17, 'Nishant', 78, None, None), (18, 'Raj', 98, None, None), (19, 'Nishant', 78, 'Mawan meerut                                      ', 478.979), (110, 'Raj', 98, 'Gol puri                                          ', 765.9), (128, 'Udai', 14, None, None), (129, 'Geeta', 23, 'Nothing                                           ', None), (120, 'Vinesh', 29, 'Rita BHag                                         ', 45.9), (118, 'Udai', 14, None, None), (119, 'Geeta', 23, 'Nothing                                           ', None), (111, 'Vinesh', 29, 'Rita BHag                                         ', 45.9)]

# %%
import pandas as pd 
df=pd.DataFrame(data=g,columns=['id','name','Age',"Address","Salary"])
df
# Out:
#       0        1   2                                                  3  \
# 0     1   Manish  23  manikpur                                      ...
# 1     2  Nishant  25                                               None
# 2     3   Manish  78  Test age                                      ...
# 3     4  Nishant  78                                               None
# 4     5  Nishant  78  New Data                                      ...
# 5     6  Nishant  78                                               None
# 6     7  Nishant  78                                               None
# 7     8      Raj  98                                               None
# 8     9  Nishant  78  Mawan meerut                                  ...
# 9    10      Raj  98  Gol puri                                      ...
# 10   17  Nishant  78                                               None
# 11   18      Raj  98                                               None
# 12   19  Nishant  78  Mawan meerut                                  ...
# 13  110      Raj  98  Gol puri                                      ...
# 14  128     Udai  14                                               None
# 15  129    Geeta  23  Nothing                                       ...
# 16  120   Vinesh  29  Rita BHag                                     ...
# 17  118     Udai  14                                               None
# 18  119    Geeta  23  Nothing                                       ...
# 19  111   Vinesh  29  Rita BHag                                     ...
#
#            4
# 0        NaN
# 1    34.8900
# 2   345.8980
# 3        NaN
# 4    45.6996
# 5        NaN
# 6        NaN
# 7        NaN
# 8   478.9790
# 9   765.9000
# 10       NaN
# 11       NaN
# 12  478.9790
# 13  765.9000
# 14       NaN
# 15       NaN
# 16   45.9000
# 17       NaN
# 18       NaN
# 19   45.9000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
# id         20 non-null int64
# name       20 non-null object
# Age        20 non-null int64
# Address    11 non-null object
# Salary     9 non-null float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 880.0+ bytes

# %%
df.to_excel("New.xlsx",sheet_name="nishant_data",index=False)

# %%
python -m pip install openpyxl
